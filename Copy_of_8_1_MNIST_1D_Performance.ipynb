# %% [markdown]
# <a href="https://colab.research.google.com/github/tyVill/CSCI167/blob/main/Copy_of_8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-8yf5dofk
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-8yf5dofk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 150   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight, nonlinearity='relu')

    if layer_in.bias is not None:
        nn.init.constant_(layer_in.bias, 0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=150, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=150, out_features=150, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=150, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.540852, train error 59.80,  test loss 1.645584, test error 64.60
# Epoch     1, train loss 1.251020, train error 45.78,  test loss 1.420443, test error 55.70
# Epoch     2, train loss 1.022342, train error 36.38,  test loss 1.260164, test error 48.70
# Epoch     3, train loss 0.872303, train error 30.97,  test loss 1.169944, test error 46.50
# Epoch     4, train loss 0.773556, train error 27.40,  test loss 1.136231, test error 42.40
# Epoch     5, train loss 0.653544, train error 22.47,  test loss 1.116568, test error 42.40
# Epoch     6, train loss 0.532157, train error 16.95,  test loss 1.071929, test error 40.60
# Epoch     7, train loss 0.432673, train error 12.55,  test loss 1.054489, test error 38.80
# Epoch     8, train loss 0.457956, train error 15.68,  test loss 1.194878, test error 41.40
# Epoch     9, train loss 0.304442, train error 7.90,  test loss 1.089201, test error 38.30
# Epoch    10, train loss 0.227453, train error 4.20,  test loss 1.026717, test error 35.40
# Epoch    11, train loss 0.189711, train error 3.00,  test loss 1.034881, test error 35.30
# Epoch    12, train loss 0.165407, train error 2.00,  test loss 1.063106, test error 36.00
# Epoch    13, train loss 0.141987, train error 1.75,  test loss 1.057408, test error 36.00
# Epoch    14, train loss 0.122167, train error 0.78,  test loss 1.061019, test error 33.90
# Epoch    15, train loss 0.109255, train error 0.72,  test loss 1.115006, test error 35.80
# Epoch    16, train loss 0.097765, train error 0.40,  test loss 1.123487, test error 36.20
# Epoch    17, train loss 0.081816, train error 0.22,  test loss 1.123546, test error 36.20
# Epoch    18, train loss 0.071352, train error 0.10,  test loss 1.151671, test error 35.60
# Epoch    19, train loss 0.063492, train error 0.05,  test loss 1.160973, test error 36.30
# Epoch    20, train loss 0.056343, train error 0.00,  test loss 1.169002, test error 35.30
# Epoch    21, train loss 0.053014, train error 0.00,  test loss 1.176839, test error 35.80
# Epoch    22, train loss 0.050048, train error 0.00,  test loss 1.188173, test error 35.10
# Epoch    23, train loss 0.047262, train error 0.00,  test loss 1.190735, test error 35.10
# Epoch    24, train loss 0.044949, train error 0.00,  test loss 1.195601, test error 35.60
# Epoch    25, train loss 0.043763, train error 0.00,  test loss 1.211154, test error 35.50
# Epoch    26, train loss 0.042043, train error 0.00,  test loss 1.217073, test error 34.90
# Epoch    27, train loss 0.039588, train error 0.00,  test loss 1.215000, test error 35.60
# Epoch    28, train loss 0.037481, train error 0.00,  test loss 1.222112, test error 35.40
# Epoch    29, train loss 0.036225, train error 0.00,  test loss 1.237536, test error 34.90
# Epoch    30, train loss 0.034965, train error 0.00,  test loss 1.236107, test error 35.10
# Epoch    31, train loss 0.034272, train error 0.00,  test loss 1.240612, test error 35.60
# Epoch    32, train loss 0.033586, train error 0.00,  test loss 1.244814, test error 35.70
# Epoch    33, train loss 0.033188, train error 0.00,  test loss 1.243763, test error 35.00
# Epoch    34, train loss 0.032327, train error 0.00,  test loss 1.252609, test error 35.30
# Epoch    35, train loss 0.031813, train error 0.00,  test loss 1.253781, test error 35.60
# Epoch    36, train loss 0.031178, train error 0.00,  test loss 1.255844, test error 35.40
# Epoch    37, train loss 0.030524, train error 0.00,  test loss 1.259967, test error 35.60
# Epoch    38, train loss 0.030020, train error 0.00,  test loss 1.260998, test error 35.20
# Epoch    39, train loss 0.029509, train error 0.00,  test loss 1.266625, test error 35.60
# Epoch    40, train loss 0.029185, train error 0.00,  test loss 1.267855, test error 35.50
# Epoch    41, train loss 0.028919, train error 0.00,  test loss 1.269116, test error 35.70
# Epoch    42, train loss 0.028665, train error 0.00,  test loss 1.269554, test error 35.10
# Epoch    43, train loss 0.028434, train error 0.00,  test loss 1.271469, test error 35.40
# Epoch    44, train loss 0.028226, train error 0.00,  test loss 1.272078, test error 35.10
# Epoch    45, train loss 0.027950, train error 0.00,  test loss 1.275606, test error 35.40
# Epoch    46, train loss 0.027729, train error 0.00,  test loss 1.275444, test error 34.80
# Epoch    47, train loss 0.027501, train error 0.00,  test loss 1.277387, test error 35.60
# Epoch    48, train loss 0.027269, train error 0.00,  test loss 1.278952, test error 35.30
# Epoch    49, train loss 0.027058, train error 0.00,  test loss 1.279246, test error 35.30

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
#
# **I think it is probably not a great idea to optimize hyperparameters in this way. We can probably make it really good for this instance or data, but we would lose accuracy on the rest of the data sets or just other data in general.So the final result may be good for that data but overall test performance for all data would not be represented.**
