# %% [markdown]
# <a href="https://colab.research.google.com/github/tyVill/CSCI167/blob/main/Copy_of_10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-9lh6yswt
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-9lh6yswt
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=3e80c55585bb98a7f56f9f0a73cebbe89dba0247c9c214ee4084d9c4de464dc0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zlpxap8w/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0), # Output size = (40 - 3)/2 + 1 = 19
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0), # Output size = (19 - 3)/2 + 1 = 9
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0), # Output size = (9 - 3)/2 + 1 = 4
    nn.ReLU(),
    nn.Flatten(), # Converts 15 channels of length 4 to 15*4 = 60
    nn.Linear(60, 10) # Input size = 60, output size = 10
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.056854, train error 76.38,  val loss 2.055651, percent error 77.30
# Epoch     1, train loss 1.647913, train error 64.45,  val loss 1.668576, percent error 64.70
# Epoch     2, train loss 1.376761, train error 55.47,  val loss 1.367683, percent error 55.60
# Epoch     3, train loss 1.244012, train error 49.67,  val loss 1.270905, percent error 54.00
# Epoch     4, train loss 1.133565, train error 44.45,  val loss 1.163358, percent error 47.60
# Epoch     5, train loss 1.117674, train error 44.58,  val loss 1.135187, percent error 46.30
# Epoch     6, train loss 0.969760, train error 38.15,  val loss 0.999920, percent error 40.30
# Epoch     7, train loss 0.864956, train error 32.97,  val loss 0.910132, percent error 35.30
# Epoch     8, train loss 0.816112, train error 31.70,  val loss 0.853765, percent error 32.40
# Epoch     9, train loss 0.653081, train error 24.88,  val loss 0.698004, percent error 28.00
# Epoch    10, train loss 0.615587, train error 24.97,  val loss 0.691495, percent error 26.90
# Epoch    11, train loss 0.672236, train error 26.25,  val loss 0.774749, percent error 30.80
# Epoch    12, train loss 0.464584, train error 17.20,  val loss 0.526471, percent error 21.40
# Epoch    13, train loss 0.400883, train error 14.80,  val loss 0.493142, percent error 19.70
# Epoch    14, train loss 0.400069, train error 14.95,  val loss 0.498712, percent error 19.20
# Epoch    15, train loss 0.367281, train error 14.15,  val loss 0.475966, percent error 19.00
# Epoch    16, train loss 0.347759, train error 12.25,  val loss 0.429259, percent error 15.50
# Epoch    17, train loss 0.307924, train error 10.62,  val loss 0.402442, percent error 13.50
# Epoch    18, train loss 0.278462, train error 10.32,  val loss 0.380996, percent error 12.80
# Epoch    19, train loss 0.308692, train error 11.57,  val loss 0.426528, percent error 14.00
# Epoch    20, train loss 0.217329, train error 8.18,  val loss 0.389521, percent error 12.50
# Epoch    21, train loss 0.174870, train error 6.05,  val loss 0.345645, percent error 12.50
# Epoch    22, train loss 0.174464, train error 5.65,  val loss 0.348713, percent error 12.20
# Epoch    23, train loss 0.165394, train error 6.00,  val loss 0.348238, percent error 11.00
# Epoch    24, train loss 0.185338, train error 7.25,  val loss 0.357392, percent error 10.60
# Epoch    25, train loss 0.146540, train error 5.00,  val loss 0.338982, percent error 10.40
# Epoch    26, train loss 0.137986, train error 4.80,  val loss 0.325534, percent error 9.50
# Epoch    27, train loss 0.129512, train error 4.07,  val loss 0.317650, percent error 9.20
# Epoch    28, train loss 0.118722, train error 3.88,  val loss 0.337449, percent error 9.70
# Epoch    29, train loss 0.118250, train error 3.82,  val loss 0.335530, percent error 10.10
# Epoch    30, train loss 0.110207, train error 3.55,  val loss 0.340573, percent error 9.20
# Epoch    31, train loss 0.118835, train error 4.10,  val loss 0.333070, percent error 9.40
# Epoch    32, train loss 0.124833, train error 4.78,  val loss 0.372029, percent error 10.80
# Epoch    33, train loss 0.108490, train error 4.00,  val loss 0.343311, percent error 9.10
# Epoch    34, train loss 0.111471, train error 4.05,  val loss 0.358923, percent error 10.60
# Epoch    35, train loss 0.110020, train error 3.82,  val loss 0.395507, percent error 10.50
# Epoch    36, train loss 0.092731, train error 3.07,  val loss 0.347045, percent error 9.50
# Epoch    37, train loss 0.079817, train error 2.20,  val loss 0.342440, percent error 8.90
# Epoch    38, train loss 0.087761, train error 2.68,  val loss 0.383652, percent error 10.30
# Epoch    39, train loss 0.095767, train error 3.43,  val loss 0.390594, percent error 10.80
# Epoch    40, train loss 0.062773, train error 1.70,  val loss 0.354086, percent error 9.40
# Epoch    41, train loss 0.063817, train error 2.00,  val loss 0.372652, percent error 9.60
# Epoch    42, train loss 0.057432, train error 1.38,  val loss 0.355613, percent error 9.30
# Epoch    43, train loss 0.060598, train error 1.50,  val loss 0.374615, percent error 9.30
# Epoch    44, train loss 0.053696, train error 1.30,  val loss 0.360821, percent error 9.30
# Epoch    45, train loss 0.054290, train error 1.25,  val loss 0.365476, percent error 8.80
# Epoch    46, train loss 0.052799, train error 1.30,  val loss 0.377629, percent error 9.30
# Epoch    47, train loss 0.052737, train error 1.40,  val loss 0.368240, percent error 9.20
# Epoch    48, train loss 0.049446, train error 1.07,  val loss 0.374649, percent error 9.60
# Epoch    49, train loss 0.052217, train error 1.15,  val loss 0.390881, percent error 9.30
# Epoch    50, train loss 0.047048, train error 0.93,  val loss 0.389190, percent error 9.90
# Epoch    51, train loss 0.044164, train error 0.78,  val loss 0.380374, percent error 9.30
# Epoch    52, train loss 0.041985, train error 0.90,  val loss 0.388818, percent error 9.20
# Epoch    53, train loss 0.042915, train error 0.78,  val loss 0.397531, percent error 9.30
# Epoch    54, train loss 0.045408, train error 1.10,  val loss 0.406948, percent error 9.40
# Epoch    55, train loss 0.044013, train error 0.97,  val loss 0.403339, percent error 9.30
# Epoch    56, train loss 0.039126, train error 0.72,  val loss 0.404358, percent error 9.10
# Epoch    57, train loss 0.037825, train error 0.68,  val loss 0.403325, percent error 9.30
# Epoch    58, train loss 0.039969, train error 0.80,  val loss 0.418467, percent error 9.50
# Epoch    59, train loss 0.040228, train error 0.93,  val loss 0.417265, percent error 9.60
# Epoch    60, train loss 0.033116, train error 0.47,  val loss 0.409722, percent error 9.50
# Epoch    61, train loss 0.032413, train error 0.43,  val loss 0.409102, percent error 9.40
# Epoch    62, train loss 0.034114, train error 0.55,  val loss 0.407599, percent error 9.50
# Epoch    63, train loss 0.031356, train error 0.35,  val loss 0.406915, percent error 9.40
# Epoch    64, train loss 0.031537, train error 0.40,  val loss 0.417289, percent error 9.20
# Epoch    65, train loss 0.031196, train error 0.38,  val loss 0.421488, percent error 9.50
# Epoch    66, train loss 0.030468, train error 0.43,  val loss 0.413114, percent error 9.30
# Epoch    67, train loss 0.030857, train error 0.50,  val loss 0.424575, percent error 9.40
# Epoch    68, train loss 0.030137, train error 0.38,  val loss 0.422492, percent error 9.40
# Epoch    69, train loss 0.029554, train error 0.47,  val loss 0.424613, percent error 9.70
# Epoch    70, train loss 0.028469, train error 0.38,  val loss 0.425323, percent error 9.60
# Epoch    71, train loss 0.029791, train error 0.35,  val loss 0.427353, percent error 9.50
# Epoch    72, train loss 0.029023, train error 0.47,  val loss 0.433385, percent error 9.70
# Epoch    73, train loss 0.028635, train error 0.30,  val loss 0.425696, percent error 9.40
# Epoch    74, train loss 0.027526, train error 0.35,  val loss 0.431695, percent error 9.40
# Epoch    75, train loss 0.026963, train error 0.32,  val loss 0.438278, percent error 9.40
# Epoch    76, train loss 0.027183, train error 0.25,  val loss 0.437696, percent error 9.70
# Epoch    77, train loss 0.026801, train error 0.32,  val loss 0.432497, percent error 9.50
# Epoch    78, train loss 0.025726, train error 0.32,  val loss 0.436245, percent error 10.10
# Epoch    79, train loss 0.025088, train error 0.32,  val loss 0.439938, percent error 9.70
# Epoch    80, train loss 0.024700, train error 0.32,  val loss 0.440471, percent error 9.60
# Epoch    81, train loss 0.024808, train error 0.32,  val loss 0.439895, percent error 9.80
# Epoch    82, train loss 0.024613, train error 0.28,  val loss 0.440807, percent error 9.70
# Epoch    83, train loss 0.024405, train error 0.32,  val loss 0.441881, percent error 9.70
# Epoch    84, train loss 0.024190, train error 0.32,  val loss 0.444128, percent error 9.80
# Epoch    85, train loss 0.024327, train error 0.35,  val loss 0.444132, percent error 9.80
# Epoch    86, train loss 0.023908, train error 0.32,  val loss 0.443592, percent error 9.50
# Epoch    87, train loss 0.023825, train error 0.32,  val loss 0.444220, percent error 9.80
# Epoch    88, train loss 0.023582, train error 0.28,  val loss 0.448110, percent error 9.70
# Epoch    89, train loss 0.023690, train error 0.28,  val loss 0.448607, percent error 9.70
# Epoch    90, train loss 0.024052, train error 0.32,  val loss 0.450491, percent error 10.00
# Epoch    91, train loss 0.023173, train error 0.30,  val loss 0.449285, percent error 9.60
# Epoch    92, train loss 0.022904, train error 0.30,  val loss 0.450053, percent error 9.70
# Epoch    93, train loss 0.022703, train error 0.32,  val loss 0.449861, percent error 9.70
# Epoch    94, train loss 0.022619, train error 0.30,  val loss 0.451807, percent error 9.60
# Epoch    95, train loss 0.023561, train error 0.28,  val loss 0.455111, percent error 9.70
# Epoch    96, train loss 0.022991, train error 0.28,  val loss 0.455730, percent error 9.90
# Epoch    97, train loss 0.022329, train error 0.28,  val loss 0.455712, percent error 9.70
# Epoch    98, train loss 0.022111, train error 0.28,  val loss 0.453893, percent error 9.80
# Epoch    99, train loss 0.022251, train error 0.28,  val loss 0.456360, percent error 9.80
